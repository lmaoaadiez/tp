# %%
import pandas as pd

df = pd.DataFrame({
    'Name': ['Joan', 'Matt', 'Jeff', 'Melissa', 'Devi'],
    'Gender': ['Female', 'Male', 'Male', 'Female', 'Female'],
    'House Type': ['Apartment', 'Detached', 'Apartment', None, 'Semi-Detached']
})

print(df)
# Out:
#       Name  Gender     House Type
# 0     Joan  Female      Apartment
# 1     Matt    Male       Detached
# 2     Jeff    Male      Apartment
# 3  Melissa  Female           None
# 4     Devi  Female  Semi-Detached

# %%
encoded_df = pd.get_dummies(df,columns=['Name'])
print(encoded_df)
# Out:
#    Gender     House Type  Name_Devi  Name_Jeff  Name_Joan  Name_Matt  \
# 0  Female      Apartment      False      False       True      False
# 1    Male       Detached      False      False      False       True
# 2    Male      Apartment      False       True      False      False
# 3  Female           None      False      False      False      False
# 4  Female  Semi-Detached       True      False      False      False
#
#    Name_Melissa
# 0         False
# 1         False
# 2         False
# 3          True
# 4         False

# %%
from sklearn.metrics import max_error

# %%
y_t=[3,-0.5,2,7]
y_p=[2.5,1.5,2,8]

# %%
print('max error',max_error(y_true=y_t,y_pred=y_p))
# Out:
# max error 2.0
